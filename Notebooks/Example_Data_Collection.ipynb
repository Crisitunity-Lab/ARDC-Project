# %% [markdown]
# # Getting the CrisisLexT26 Dataset
# This notebook provides an example on who to download, unzip and combine relevant CSV's into a single data frame. The source dataset can be found [here](https://crisislex.org/data-collections.html#CrisisLexT26). The tweets in the dataset have been labelled with:
#
# - **Information Source**, and
# - **Informativeness**, and
# - **Information Type**.
#
# Additional metadata like crisis event, crisis type and country impacted have been included in the dataset for information purposes.
#
# ### Clone the project GitHub repo
# The project uses code stored in the publicly available GitHub repo [here](https://github.com/Crisitunity-Lab/ARDC-Project). To access bespoke function, clone the GitHub repo to the local environment.

# %%
# Clone GitHub repo
user = "Crisitunity-Lab"
repo = "ARDC-Project"

# !git clone https://github.com/$user/$repo /content/repo
# Out:
# Cloning into '/content/repo'...
# remote: Enumerating objects: 494, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 494 (delta 25), reused 34 (delta 14), pack-reused 437
# Receiving objects: 100% (494/494), 5.20 MiB | 10.05 MiB/s, done.
# Resolving deltas: 100% (253/253), done.

# %% [markdown]
# ### Install requirements
# All python library requirements are contained in a requirements.txt file and can be run with the below.

# %%
# %pip install -r /content/repo/requirements.txt
# Out:
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from -r /content/repo/requirements.txt (line 1)) (7.0.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from -r /content/repo/requirements.txt (line 2)) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r /content/repo/requirements.txt (line 3)) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r /content/repo/requirements.txt (line 4)) (1.5.3)
# Collecting pycountry==22.3.5 (from -r /content/repo/requirements.txt (line 5))
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 23.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/repo/requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from -r /content/repo/requirements.txt (line 7)) (0.12.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from -r /content/repo/requirements.txt (line 8)) (1.2.2)
# Collecting transformers (from -r /content/repo/requirements.txt (line 11))
#   Downloading transformers-4.34.1-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 70.1 MB/s eta 0:00:00
# Collecting accelerate (from -r /content/repo/requirements.txt (line 12))
#   Downloading accelerate-0.24.0-py3-none-any.whl (260 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 31.5 MB/s eta 0:00:00
# Collecting einops (from -r /content/repo/requirements.txt (line 13))
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.6 MB/s eta 0:00:00
# Collecting langchain (from -r /content/repo/requirements.txt (line 14))
#   Downloading langchain-0.0.325-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 76.8 MB/s eta 0:00:00
# Collecting bitsandbytes (from -r /content/repo/requirements.txt (line 15))
#   Downloading bitsandbytes-0.41.1-py3-none-any.whl (92.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pycountry==22.3.5->-r /content/repo/requirements.txt (line 5)) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->-r /content/repo/requirements.txt (line 6)) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->-r /content/repo/requirements.txt (line 6)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->-r /content/repo/requirements.txt (line 6)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->-r /content/repo/requirements.txt (line 6)) (2023.7.22)
# Requirement already satisfied: pydantic>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from inflect->-r /content/repo/requirements.txt (line 1)) (1.10.13)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from inflect->-r /content/repo/requirements.txt (line 1)) (4.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/repo/requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/repo/requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/repo/requirements.txt (line 2)) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/repo/requirements.txt (line 2)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/repo/requirements.txt (line 2)) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/repo/requirements.txt (line 2)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/repo/requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/repo/requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r /content/repo/requirements.txt (line 4)) (2023.3.post1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r /content/repo/requirements.txt (line 8)) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r /content/repo/requirements.txt (line 8)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r /content/repo/requirements.txt (line 8)) (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->-r /content/repo/requirements.txt (line 11)) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers->-r /content/repo/requirements.txt (line 11))
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 37.5 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->-r /content/repo/requirements.txt (line 11)) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r /content/repo/requirements.txt (line 11)) (2023.6.3)
# Collecting tokenizers<0.15,>=0.14 (from transformers->-r /content/repo/requirements.txt (line 11))
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 117.3 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers->-r /content/repo/requirements.txt (line 11))
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 90.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers->-r /content/repo/requirements.txt (line 11)) (4.66.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->-r /content/repo/requirements.txt (line 12)) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate->-r /content/repo/requirements.txt (line 12)) (2.1.0+cu118)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/repo/requirements.txt (line 14)) (2.0.22)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/repo/requirements.txt (line 14)) (3.8.6)
# Requirement already satisfied: anyio<4.0 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/repo/requirements.txt (line 14)) (3.7.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/repo/requirements.txt (line 14)) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain->-r /content/repo/requirements.txt (line 14))
#   Downloading dataclasses_json-0.6.1-py3-none-any.whl (27 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain->-r /content/repo/requirements.txt (line 14))
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langsmith<0.1.0,>=0.0.52 (from langchain->-r /content/repo/requirements.txt (line 14))
#   Downloading langsmith-0.0.53-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain->-r /content/repo/requirements.txt (line 14)) (8.2.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r /content/repo/requirements.txt (line 14)) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r /content/repo/requirements.txt (line 14)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r /content/repo/requirements.txt (line 14)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r /content/repo/requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r /content/repo/requirements.txt (line 14)) (1.3.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain->-r /content/repo/requirements.txt (line 14)) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain->-r /content/repo/requirements.txt (line 14)) (1.1.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain->-r /content/repo/requirements.txt (line 14))
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.1 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain->-r /content/repo/requirements.txt (line 14))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers->-r /content/repo/requirements.txt (line 11)) (2023.6.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain->-r /content/repo/requirements.txt (line 14))
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->-r /content/repo/requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain->-r /content/repo/requirements.txt (line 14)) (3.0.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers->-r /content/repo/requirements.txt (line 11))
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 35.4 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->-r /content/repo/requirements.txt (line 12)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->-r /content/repo/requirements.txt (line 12)) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->-r /content/repo/requirements.txt (line 12)) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate->-r /content/repo/requirements.txt (line 12)) (2.1.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain->-r /content/repo/requirements.txt (line 14))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate->-r /content/repo/requirements.txt (line 12)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate->-r /content/repo/requirements.txt (line 12)) (1.3.0)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (pyproject.toml) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681833 sha256=043818777e5fac8cc91d8dca1c4a8a1fca1cec67e81aea4d8ee6416920358d36
#   Stored in directory: /root/.cache/pip/wheels/03/57/cc/290c5252ec97a6d78d36479a3c5e5ecc76318afcb241ad9dbe
# Successfully built pycountry
# Installing collected packages: bitsandbytes, safetensors, pycountry, mypy-extensions, marshmallow, jsonpointer, einops, typing-inspect, langsmith, jsonpatch, huggingface-hub, tokenizers, dataclasses-json, accelerate, transformers, langchain
# Successfully installed accelerate-0.24.0 bitsandbytes-0.41.1 dataclasses-json-0.6.1 einops-0.7.0 huggingface-hub-0.17.3 jsonpatch-1.33 jsonpointer-2.4 langchain-0.0.325 langsmith-0.0.53 marshmallow-3.20.1 mypy-extensions-1.0.0 pycountry-22.3.5 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.1 typing-inspect-0.9.0

# %%
# Import langchain library
from langchain import HuggingFacePipeline

# Import bespoke functions
import repo.src.structure_extractor.data_utils as du
import repo.src.structure_extractor.model_utils as mu

# %% [markdown]
# ### Get data
# Using the pre-built functions in the data utils file, provide a link to the zipped data and a destination directory. Data will be downloaded and unzipped to the destination directory. The source dataset contains multiple files in each directory. The files include in each directory include:
# - A README.md file containing general information about the files in the folder.
# - A JSON file containing information about the event and other pieces of metadata.
# - A labelled tweets comma separated values (CSV) file named \<crisis_event>-
# tweets_labeled.csv. This file contains labelled tweets.
# - A CSV file containing a list of identifiers for all tweets associated with the event. The file is
# named \<crisis_event>-tweetids_entire_period.csv.
#
# For this example only the _\<crisis_event>-tweets_labeled.csv_ is required.

# %%
# Get data from online source and unzip to local directory
zip_file_url = "https://github.com/sajao/CrisisLex/blob/master/releases/CrisisLexT26-v1.0.zip?raw=true"
dest_folder = "/content/data/"

du.unzip_from_url(src=zip_file_url, dest=dest_folder)
# Out:
# Download and Unzip complete

# %% [markdown]
# Data is now stored at /content/data/CrisisLexT26 within the Google Colab environment.
#
# ### Combine data into single dataframe
# As the data is spread across multiple CSV files the *combine_csv_files* function will bring together the tweets_labelled file in each directory in a single file.
#
# **NOTE**: Some tweets in the dataset have very few words. Having little data in the tweet makes it difficult for anyone, let alone a large language model, to understand what the tweet is about. The minimum length of a tweet can be set and tweets with fewer words than the minimum are excluded. "Words" doesn't include hashtags, links and user tags.

# %%
# Set the folder name for where the data is stored
data_folder_name = "CrisisLexT26"
data_loc = dest_folder + data_folder_name
min_tweet_length = 6

# Combine csv's into a single dataframe. By default the folder the data is stored in is included as a
# new field called "label", but this can be turned off by setting the retrieve_label parameter to False.
df = du.combine_csv_files(data_loc, min_tweet_len=min_tweet_length)

# %%
# Data is now in a dataframe
df.head(10)
# Out:
#               Tweet ID                                         Tweet Text  \
# 0   203440928084602880  E #Navelli... a che punto siamo? Dov'è il pian...
# 1   203843778409283584  RT @andmarini: #Modena Strage di Brindisi, all...
# 2   204030290715348993            #Terremoto ! in alto si sente parecchio
# 3   204030617850089472  Inequivocabilmente questa era una scossa di #t...
# 5   204032853439283201  “@perugini: 44.956°N, 11.241°E - 4.2 Magnitudo...
# 6   204033939772407808  RT @Reuters: BREAKING NEWS: 6.3 magnitude eart...
# 7   204033969124155392  RT @Reuters: BREAKING NEWS: 6.3 magnitude eart...
# 9   204034510176780288  RT @Reuters: BREAKING NEWS: 6.3 magnitude eart...
# 11  204034585670062080  RT @USGSted: Strong earthquake, NORTHERN ITALY...
# 12  204034644398702592  Oddio #terremoto.  L'ho sentito solo io alle 4...
#
#    Information Source          Information Type  \
# 0           Outsiders  Other Useful Information
# 1         Not labeled               Not labeled
# 2           Outsiders      Sympathy and support
# 3          Eyewitness      Sympathy and support
# 5          Eyewitness  Other Useful Information
# 6               Media  Other Useful Information
# 7               Media  Other Useful Information
# 9               Media  Other Useful Information
# 11              Media        Caution and advice
# 12         Eyewitness      Sympathy and support
#
#                   Informativeness                   label  year country_code  \
# 0   Related - but not informative  2012_Italy_earthquakes  2012           IT
# 1                     Not related  2012_Italy_earthquakes  2012           IT
# 2   Related - but not informative  2012_Italy_earthquakes  2012           IT
# 3   Related - but not informative  2012_Italy_earthquakes  2012           IT
# 5         Related and informative  2012_Italy_earthquakes  2012           IT
# 6         Related and informative  2012_Italy_earthquakes  2012           IT
# 7         Related and informative  2012_Italy_earthquakes  2012           IT
# 9         Related and informative  2012_Italy_earthquakes  2012           IT
# 11        Related and informative  2012_Italy_earthquakes  2012           IT
# 12  Related - but not informative  2012_Italy_earthquakes  2012           IT
#
#    crisis_type
# 0   Earthquake
# 1   Earthquake
# 2   Earthquake
# 3   Earthquake
# 5   Earthquake
# 6   Earthquake
# 7   Earthquake
# 9   Earthquake
# 11  Earthquake
# 12  Earthquake

# %%
# How many records are there?
len(df)
# Out:
# 26001
